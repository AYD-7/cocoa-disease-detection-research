# %%
import sys

print("Python:", sys.version)
print("Executable:", sys.executable)
# Out:
# Python: 3.12.3 (main, Jun 19 2026, 12:46:00) [GCC 13.3.0]
# Executable: /home/l2e_ayd/cocoa_research/.venv/bin/python

# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("Training will use CPU.")

# %%
import ultralytics

print("Ultralytics version:", ultralytics.__version__)

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

# %%
results = model.train(
    data="../data/processed/final/data.yaml",
    epochs=50,
    imgsz=640,
    patience=10
)

# %%
import torch
import ultralytics

print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("Ultralytics:", ultralytics.__version__)

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# %%
import sys

print("Python:")
print(sys.executable)

print("\nPython version:")
print(sys.version)

try:
    import torch
    print("\nPyTorch:", torch.__version__)
    print("CUDA available:", torch.cuda.is_available())
except Exception as e:
    print("\nPyTorch:", e)

try:
    import ultralytics
    print("\nUltralytics:", ultralytics.__version__)
except Exception as e:
    print("\nUltralytics:", e)
# Out:
# Python:
# /home/l2e_ayd/cocoa_research/.venv/bin/python
#
# Python version:
# 3.12.3 (main, Jun 19 2026, 12:46:00) [GCC 13.3.0]
#
# PyTorch: 2.13.0+cu130
# CUDA available: False
#
# Ultralytics: 8.4.136

# %%
import sys

print("Python:")
print(sys.executable)

print("\nPyTorch:")
import torch
print(torch.__version__)

print("\nCUDA available:")
print(torch.cuda.is_available())

print("\nUltralytics:")
import ultralytics
print(ultralytics.__version__)
# Out:
# Python:
# /home/l2e_ayd/cocoa_research/.venv/bin/python
#
# PyTorch:
# 2.13.0+cu130
#
# CUDA available:
# False
#
# Ultralytics:
# 8.4.136

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

print("Model loaded successfully.")
# Out:
# ...
# Model loaded successfully.

# %%
results = model.train(
    data="../data/processed/final/data.yaml",
    epochs=1,
    imgsz=640,
    batch=4,
    device="cpu",
    workers=2
)
# Out:
# Ultralytics 8.4.136 🚀 Python-3.12.3 torch-2.13.0+cu130 CPU (Intel Core i5-8265U 1.60GHz)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

results = model.train(
    data="../data/processed/final/data.yaml",
    epochs=10,
    imgsz=512,
    batch=8,
    device="cpu",
    workers=4,
    patience=3,
    project="runs/detect",
    name="cocoa_baseline"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.137 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.136 🚀 Python-3.12.3 torch-2.13.0+cu130 CPU (Intel Core i5-8265U 1.60GHz)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

results = model.train(
    data="../data/processed/final/data.yaml",
    epochs=1,
    imgsz=512,
    batch=8,
    device="cpu",
    workers=4,
    project="runs/detect",
    name="cocoa_speed_test"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.138 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.136 🚀 Python-3.12.3 torch-2.13.0+cu130 CPU (Intel Core i5-8265U 1.60GHz)
# ...

# %%
from ultralytics import YOLO

model = YOLO(
    "/home/l2e_ayd/cocoa_research/notebooks/runs/detect/runs/detect/cocoa_baseline-6/weights/best.pt"
)

# %%
import time

print("Jupyter is working!")
print("There is a delay!")
time.sleep(2)
print("Took two seconds")
# Out:
# Jupyter is working!
# There is a delay!
# Took two seconds

# %%
test_metrics = model.val(
    data="/home/l2e_ayd/cocoa_research/data/processed/final/data.yaml",
    split="test",
    imgsz=512,
    batch=8,
    device="cpu",
    workers=4,
    plots=True,
)

print("mAP50:", test_metrics.box.map50)
print("mAP50-95:", test_metrics.box.map)
# Out:
# Ultralytics 8.4.136 🚀 Python-3.12.3 torch-2.13.0+cu130 CPU (Intel Core i5-8265U 1.60GHz)
# YOLO11n summary (fused): 101 layers, 2,582,737 parameters, 0 gradients, 6.4 GFLOPs
# val: Fast image access ✅ (ping: 0.2±0.0 ms, read: 153.8±135.6 MB/s, size: 1749.4 KB)
# val: Scanning /home/l2e_ayd/cocoa_research/data/processed/final/test/labels... 559 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 559/559 185.7it/s 3.0s0.1s
# val: /home/l2e_ayd/cocoa_research/data/processed/final/test/images/kara_healthy_02_healthy_02_20211021_122932-14_41_24.jpg: corrupt JPEG restored and saved
# val: /home/l2e_ayd/cocoa_research/data/processed/final/test/images/kara_healthy_02_healthy_02_20211027_130311-5_4_48.jpg: corrupt JPEG restored and saved
# val: /home/l2e_ayd/cocoa_research/data/processed/final/test/images/kara_healthy_02_healthy_02_799388E6-D151-4D77-BACF-110C6AAA0069-1_21_5.jpeg: corrupt JPEG restored and saved
# ...

# %%
test_images = (
    "/home/l2e_ayd/cocoa_research/data/processed/final/test/images"
)

results = model.predict(
    source=test_images,
    imgsz=512,
    conf=0.25,
    save=True,
    device="cpu"
)
# Out:
# image 1/559 /home/l2e_ayd/cocoa_research/data/processed/final/test/images/kara_healthy_02_healthy_02_0293121F-C87F-4EC0-B23E-6E91D708A331-19_1_53.jpeg: 512x384 1 healthy, 250.8ms
# image 2/559 /home/l2e_ayd/cocoa_research/data/processed/final/test/images/kara_healthy_02_healthy_02_06642418-48EE-44A7-ACAE-DCB5D1E47350-8_29_25.jpeg: 384x512 2 healthys, 142.4ms
# image 3/559 /home/l2e_ayd/cocoa_research/data/processed/final/test/images/kara_healthy_02_healthy_02_072164EF-A2CA-4AA8-AF89-E69BFCF99B32-9_57_1.jpeg: 512x384 3 healthys, 69.4ms
# image 4/559 /home/l2e_ayd/cocoa_research/data/processed/final/test/images/kara_healthy_02_healthy_02_09787E04-28E4-44CA-A3ED-F2BBFB661D6B-0_28_42.jpeg: 384x512 4 healthys, 68.0ms
# image 5/559 /home/l2e_ayd/cocoa_research/data/processed/final/test/images/kara_healthy_02_healthy_02_1375FB71-7B7C-4DD0-BD6C-B5E81A59A7EA-15_48_35.jpeg: 384x512 1 healthy, 70.1ms
# ...

# %%
from pathlib import Path
import pandas as pd

run_dir = Path(
    "/home/l2e_ayd/cocoa_research/notebooks/runs/detect/runs/detect/cocoa_baseline-6"
)

results_file = run_dir / "results.csv"

df = pd.read_csv(results_file)

print("Epochs:", len(df))
print("\nColumns:")
print(df.columns.tolist())

print("\nLast 5 epochs:")
display(df.tail())
# Out:
# Epochs: 10
#
# Columns:
# ['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss', 'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss', 'lr/pg0', 'lr/pg1', 'lr/pg2']
#
# Last 5 epochs:
#    epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 5      6  71161.8         1.28826         1.17935         1.49780
# 6      7  73052.9         1.24801         1.12042         1.46342
# 7      8  75036.4         1.21738         1.05444         1.43912
# 8      9  77045.6         1.18570         1.00096         1.41974
# 9     10  78874.2         1.16225         0.96091         1.39701
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 5               0.68561            0.66105           0.68899
# 6               0.68413            0.65748           0.68694
# 7               0.73762            0.69030           0.70755
# ...

# %%
print("Jupyter is working!")
# Out:
# Jupyter is working!

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(df["epoch"], df["metrics/mAP50(B)"])
plt.xlabel("Epoch")
plt.ylabel("mAP50")
plt.title("Cocoa YOLO11n Validation mAP50")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df["epoch"], df["metrics/mAP50-95(B)"])
plt.xlabel("Epoch")
plt.ylabel("mAP50-95")
plt.title("Cocoa YOLO11n Validation mAP50-95")
plt.grid()
plt.show()

# %%
from ultralytics import YOLO

model = YOLO(
    "/home/l2e_ayd/cocoa_research/notebooks/runs/detect/runs/detect/cocoa_baseline-6/weights/best.pt"
)

results = model.train(
    data="/home/l2e_ayd/cocoa_research/data/processed/final/data.yaml",
    epochs=5,
    imgsz=512,
    batch=8,
    device="cpu",
    workers=4,
    patience=2,
    project="/home/l2e_ayd/cocoa_research/notebooks/runs/detect",
    name="cocoa_finetune_512"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.138 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.136 🚀 Python-3.12.3 torch-2.13.0+cu130 CPU (Intel Core i5-8265U 1.60GHz)
# ...
